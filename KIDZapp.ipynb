# %%
from tkinter import *
from tkinter import PhotoImage
from playsound import playsound

def A_voice():
    playsound("A.mp3")
def B_voice():
    playsound("B.mp3")
def C_voice():
    playsound("C.mp3")
def D_voice():
    playsound("D.mp3")
def E_voice():
    playsound("E.mp3")
def F_voice():
    playsound("F.mp3")
def G_voice():
    playsound("G.mp3")
def H_voice():
    playsound("H.mp3")
def I_voice():
    playsound("I.mp3")
def J_voice():
    playsound("J.mp3")
def K_voice():
    playsound("K.mp3")
def L_voice():
    playsound("L.mp3")
def M_voice():
    playsound("M.mp3")
def N_voice():
    playsound("N.mp3")
def O_voice():
    playsound("O.mp3")
def P_voice():
    playsound("p.mp3")
def Q_voice():
    playsound("Q.mp3")
def R_voice():
    playsound("R.mp3")
def S_voice():
    playsound("S.mp3")
def T_voice():
    playsound("T.mp3")
def U_voice():
    playsound("U.mp3")
def V_voice():
    playsound("V.mp3")
def W_voice():
    playsound("W.mp3")
def X_voice():
    playsound("X.mp3")
def Y_voice():
    playsound("Y.mp3")
def Z_voice():
    playsound("Z.mp3")
    
def buttons():
    win=Tk()
    win.title("KIDS ZONE")
    win.geometry('720x500')
    #win.config(bg="#CECCBE")
    win.config(bg="#ccccff")
    a=Button(win,text="A",font=(20),height=2,width=5,command=A_voice,activebackground="orange")
    a.place(x=10,y=10)
    b=Button(win,text="B",font=(20),height=2,width=5,command=B_voice,activebackground="purple")
    b.place(x=110,y=10)
    c=Button(win,text="C",font=(20),height=2,width=5,command=C_voice,activebackground="light pink")
    c.place(x=210,y=10)
    d=Button(win,text="D",font=(20),height=2,width=5,command=D_voice,activebackground="#62a832")
    d.place(x=310,y=10)
    e=Button(win,text="E",font=(20),height=2,width=5,command=E_voice,activebackground="grey")
    e.place(x=410,y=10)
    f=Button(win,text="F",font=(20),height=2,width=5,command=F_voice,activebackground="cyan")
    f.place(x=510,y=10)
    g=Button(win,text="G",font=(20),height=2,width=5,command=G_voice,activebackground="red")
    g.place(x=610,y=10)
    h=Button(win,text="H",font=(20),height=2,width=5,command=H_voice,activebackground="green")
    h.place(x=10,y=90)
    i=Button(win,text="I",font=(20),height=2,width=5,command=I_voice,activebackground="light pink")
    i.place(x=110,y=90)
    j=Button(win,text="J",font=(20),height=2,width=5,command=J_voice,activebackground="light pink")
    j.place(x=210,y=90)
    k=Button(win,text="K",font=(20),height=2,width=5,command=K_voice,activebackground="light pink")
    k.place(x=310,y=90)
    l=Button(win,text="L",font=(20),height=2,width=5,command=L_voice,activebackground="light pink")
    l.place(x=410,y=90)
    m=Button(win,text="M",font=(20),height=2,width=5,command=M_voice,activebackground="light pink")
    m.place(x=510,y=90)
    n=Button(win,text="N",font=(20),height=2,width=5,command=N_voice,activebackground="light pink")
    n.place(x=610,y=90)
    o=Button(win,text="O",font=(20),height=2,width=5,command=O_voice,activebackground="light pink")
    o.place(x=10,y=170)
    p=Button(win,text="P",font=(20),height=2,width=5,command=P_voice,activebackground="light pink")
    p.place(x=110,y=170)
    q=Button(win,text="Q",font=(20),height=2,width=5,command=Q_voice,activebackground="light pink")
    q.place(x=210,y=170)
    r=Button(win,text="R",font=(20),height=2,width=5,command=R_voice,activebackground="light pink")
    r.place(x=310,y=170)
    s=Button(win,text="S",font=(20),height=2,width=5,command=S_voice,activebackground="light pink")
    s.place(x=410,y=170)
    t=Button(win,text="T",font=(20),height=2,width=5,command=T_voice,activebackground="light pink")
    t.place(x=510,y=170)
    u=Button(win,text="U",font=(20),height=2,width=5,command=U_voice,activebackground="light pink")
    u.place(x=610,y=170)
    v=Button(win,text="V",font=(20),height=2,width=5,command=V_voice,activebackground="light pink")
    v.place(x=10,y=260)
    w=Button(win,text="W",font=(20),height=2,width=5,command=W_voice,activebackground="light pink")
    w.place(x=110,y=260)
    x=Button(win,text="X",font=(20),height=2,width=5,command=X_voice,activebackground="light pink")
    x.place(x=210,y=260)
    y=Button(win,text="Y",font=(20),height=2,width=5,command=Y_voice,activebackground="light pink")
    y.place(x=310,y=260)
    z=Button(win,text="z",font=(20),height=2,width=5,command=Z_voice,activebackground="light pink")
    z.place(x=410,y=260)
    label=Label(win,text="Only for kids",font="FixedSys 18",bg="#ccccff", fg="green").place(x=250,y=450)
    
    def switch():
        global btnState
        if btnState:
            btn.config(image=offImg, bg="yellow", activebackground="#ccccff")
            win.config(bg="#ccccff")
            btnState = False
        else:
            btn.config(image=onImg, bg="yellow", activebackground="#2B2B2B")
            win.config(bg="#2B2B2B")
            btnState = True
    
    global btnState
    btnState=False
    onImg = PhotoImage(file=r"icons8-toggle-on-24.png")
    offImg = PhotoImage(file=r"icons8-toggle-off-24.png")
    
    btn = Button(win, text="OFF", borderwidth=0, command=switch, bg="yellow", activebackground="#ccccff")
    btn.place(x=340,y=400)
    btn.config(image=offImg)

    
    win.mainloop()
buttons()
